# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-neetcode-250/blob/main/Problem877.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque

class Solution:
    def stoneGame(self, piles):
        # Idea:
        # Use the Min-Max strategy

        # Can Bob ever win this game?
        # Should I write one line:
        #  return True
        # ???
        # No. That won't be the algorithm (technically it is?).
        # I cannot come up with the algorithm, so I'm gonna go with my gut.
        return True

# %%
solution = Solution()

# %%
piles = [5,3,4,5]

print(solution.stoneGame(piles))
# Out:
# 0
# deque([3, 4, 5])
# Alice: 5
# Bob: 0
#
# 1
# deque([3, 4])
# Alice: 5
# Bob: 5
#
# 2
# deque([3])
# Alice: 9
# Bob: 5
#
# 3
# deque([])
# Alice: 9
# Bob: 8
#
# Alice: 9
# Bob: 8
# True

# %%
piles = [3,7,2,3]

print(solution.stoneGame(piles))
# Out:
# 0
# deque([3, 7, 2])
# Alice: 3
# Bob: 0
#
# 1
# deque([7, 2])
# Alice: 3
# Bob: 3
#
# 2
# deque([2])
# Alice: 10
# Bob: 3
#
# 3
# deque([])
# Alice: 10
# Bob: 5
#
# Alice: 10
# Bob: 5
# True

# %%
piles = [1,10,9,1]

print(solution.stoneGame(piles))
# Out:
# 0
# deque([1, 10, 9])
# Alice: 1
# Bob: 0
#
# 1
# deque([1, 10])
# Alice: 1
# Bob: 9
#
# 2
# deque([1])
# Alice: 11
# Bob: 9
#
# 3
# deque([])
# Alice: 11
# Bob: 10
#
# Alice: 11
# Bob: 10
# True

# %%
piles = [1,10,9,1]

print(solution.stoneGame(piles))
# Out:
# 0
# deque([1, 10, 9])
# Alice: 1
# Bob: 0
#
# 1
# deque([1, 10])
# Alice: 1
# Bob: 9
#
# 2
# deque([1])
# Alice: 11
# Bob: 9
#
# 3
# deque([])
# Alice: 11
# Bob: 10
#
# Alice: 11
# Bob: 10
# True

# %%
piles = [2,3,1,100,5,4,9,1]

print(solution.stoneGame(piles))
# Out:
# 0
# deque([3, 1, 100, 5, 4, 9, 1])
# Alice: 2
# Bob: 0
#
# 1
# deque([1, 100, 5, 4, 9, 1])
# Alice: 2
# Bob: 3
#
# 2
# deque([1, 100, 5, 4, 9])
# Alice: 3
# Bob: 3
#
# 3
# deque([1, 100, 5, 4])
# Alice: 3
# Bob: 12
#
# 4
# deque([1, 100, 5])
# Alice: 7
# Bob: 12
#
# 5
# deque([1, 100])
# Alice: 7
# Bob: 17
#
# 6
# deque([1])
# Alice: 107
# Bob: 17
#
# 7
# deque([])
# Alice: 107
# Bob: 18
#
# Alice: 107
# Bob: 18
# True

# %%
piles = [6,9,4,3,9,8]

print(solution.stoneGame(piles))
# Out:
# 0
# deque([6, 9, 4, 3, 9])
# Alice: 8
# Bob: 0
#
# 1
# deque([6, 9, 4, 3])
# Alice: 8
# Bob: 9
#
# 2
# deque([6, 9, 4])
# Alice: 11
# Bob: 9
#
# 3
# deque([9, 4])
# Alice: 11
# Bob: 15
#
# 4
# deque([4])
# Alice: 20
# Bob: 15
#
# 5
# deque([])
# Alice: 20
# Bob: 19
#
# Alice: 20
# Bob: 19
# True

# %%
piles = [6,3,9,9,3,8,8,7]

print(solution.stoneGame(piles))
# Out:
# 0
# deque([3, 9, 9, 3, 8, 8, 7])
# Alice: 6
# Bob: 0
#
# 1
# deque([3, 9, 9, 3, 8, 8])
# Alice: 6
# Bob: 7
#
# 2
# deque([3, 9, 9, 3, 8])
# Alice: 14
# Bob: 7
#
# 3
# deque([3, 9, 9, 3])
# Alice: 14
# Bob: 15
#
# 4
# deque([9, 9, 3])
# Alice: 17
# Bob: 15
#
# 5
# deque([9, 3])
# Alice: 17
# Bob: 24
#
# 6
# deque([3])
# Alice: 26
# Bob: 24
#
# 7
# deque([])
# Alice: 26
# Bob: 27
#
# Alice: 26
# Bob: 27
# False

# %%
0
deque([6, 3, 9, 9, 3, 8, 8])
Alice: 7
Bob: 0

1
deque([6, 3, 9, 9, 3, 8])
Alice: 7
Bob: 8

2
deque([6, 3, 9, 9, 3])
Alice: 15
Bob: 8

3
deque([3, 9, 9, 3])
Alice: 15
Bob: 14

4
deque([9, 9, 3])
Alice: 18
Bob: 14

5
deque([9, 3])
Alice: 18
Bob: 23

6
deque([3])
Alice: 27
Bob: 23

7
deque([])
Alice: 27
Bob: 26

Alice: 27
Bob: 26
True
# Out:
# True
