# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-neetcode-250/blob/main/Problem18_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def fourSum(self, nums, target):
        # Sort the array
        nums.sort()

        n = len(nums)
        results = []

        # We fix the left mostpointer i.
        for i in range(n - 3):
            # Skip duplicate valus for i
            if i > 0 and nums[i] == nums[i - 1]:
                continue

            # Pruning for i
            # Smallest possible sum with current i
            if nums[i] + nums[i + 1] + nums[i + 2] + nums[i + 3] > target:
                # All subsequent i will also be too large
                break

            # Largest possible sum with current i
            if nums[i] + nums[n - 3] + nums[n - 2] + nums[n - 1] < target:
                # Current i is too small, so try next i
                continue

            # We also fix the 2nd leftmost pointer j
            for j in range(i + 1, n - 2):
                # Skip duplicate values for j
                if j > i + 1 and nums[j] == nums[j - 1]:
                    continue

                # Pruning for j
                if nums[i] + nums[j] + nums[j + 1] + nums[j + 2] > target:
                    break

                if nums[i] + nums[j] + nums[n - 2] + nums[n - 1] < target:
                    continue

                # Use the Two pointer approach
                left = j + 1
                right = n - 1
                while left < right:
                    total = nums[i] + nums[j] + nums[left] + nums[right]

                    # Matched
                    if total == target:
                        results.append([nums[i], nums[j], nums[left], nums[right]])

                        # Skip duplicate values for Left
                        while left < right and nums[left] == nums[left + 1]:
                            left += 1

                        # Skip duplicate values for Right
                        while left < right and nums[right] == nums[right - 1]:
                            right -= 1

                        # Move on to the next loop
                        left += 1
                        right -= 1

                    # We need more value
                    elif total < target:
                        left += 1

                    # We overshot (total > target)
                    else:
                        right -= 1

        return results

# %%
solution = Solution()

# %%
nums = [1,0,-1,0,-2,2]
target = 0

print(solution.fourSum(nums, target))
# Out:
# [[-2, -1, 1, 2], [-2, 0, 0, 2], [-1, 0, 0, 1]]

# %%
nums = [2,2,2,2,2]
target = 8

print(solution.fourSum(nums, target))
# Out:
# [[2, 2, 2, 2]]

# %%
nums = [-2,-1,-1,1,1,2,2]
target = 0

print(solution.fourSum(nums, target))
# Out:
# [[-2, -1, 1, 2], [-1, -1, 1, 1]]
