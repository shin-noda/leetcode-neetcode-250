# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-neetcode-250/blob/main/Problem543.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
class Solution:
    def diameterOfBinaryTree(self, root):
        self.diameter = 0

        def maxDepth(node):
            if not node:
                return 0

            return 1 + max(maxDepth(node.left), maxDepth(node.right))

        def traverse(node):
            if not node:
                return

            left = maxDepth(node.left)
            right = maxDepth(node.right)

            self.diameter = max(self.diameter, left + right)

            traverse(node.left)
            traverse(node.right)


        # Start traversing nodes
        traverse(root)

        return self.diameter
