# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-neetcode-250/blob/main/Problem1046.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

class Solution:
    def lastStoneWeight(self, stones):
        max_heap = []

        for i in range(len(stones)):
            # Note: it's a max heap, so multiply by -1
            heapq.heappush(max_heap, -stones[i])

        while len(max_heap) >= 2:
            y = -heapq.heappop(max_heap)
            x = -heapq.heappop(max_heap)

            if x != y:
                heapq.heappush(max_heap, -(y - x))

        if max_heap:
            return -max_heap[0]

        return 0
