# %% [markdown]
# <a href="https://colab.research.google.com/github/shin-noda/leetcode-neetcode-250/blob/main/Problem1863.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def subsetXORSum(self, nums):
        self.result = 0

        def backtrack(index, val):
            for i in range(index, len(nums)):
                # Choose
                new_val = val ^ nums[i]
                self.result += new_val

                # Explore
                backtrack(i + 1, new_val)

                # Unchoose
                # No further action required here.

        backtrack(0, 0)

        return self.result

# %%
print(0 ^ 5)
# Out:
# 5

# %%
print(1 ^ 3)
# Out:
# 2
